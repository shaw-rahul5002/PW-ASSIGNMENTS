# %% [markdown]
# ### [Q1.] What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# ##### [Ans]
# Flask is a lightweight web framework, that alllows you to build web application quickly and easily.
#
# ADVANTAGES :- The advantages of flask includes its simplicity, flexibility, and ease of use. It is also highly customizable and has a large and supportive community.

# %% [markdown]
# ### [Q2.] Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %% [markdown]
# ##### [Ans]

# %% [markdown]
# ![assignment.png.png](attachment:47853910-c2e6-4b4e-a64d-f36c257d835d.png)

# %% [markdown]
# ### [Q3.] What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# ##### [Ans]
# In Flask, app routing refers to the process of managing URLs to functions in your application.
#
# We use app routes to define the different URLs that users can visit and the functions that should be called when they visit those URLs.

# %% [markdown]
# ### [Q4.] Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
#
# #### Company Name: ABC Corporation
#
# #### Location: India
#
# #### Contact Detail: 999-999-9999

# %% [markdown]
# ##### [Ans]

# %% [markdown]
# ![Screenshot (5).png](attachment:26a357e1-b84c-4ef5-a7a3-f3a98df1dda9.png) , ![Screenshot (4).png](attachment:51016bc1-3192-472d-b01e-b6d03656547d.png)

# %% [markdown]
# ### [Q5.] What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# ##### [Ans]
# In Flask, the 'url_for()' function is used for URL building.

# %%
from flask import Flask, url_for

app = Flask(__name__)

@app.route('/')
def home():
    return "This is the home page"

@app.route('/about')
def about():
    return "This is the about page"

with app.test_request_context():
    print(url_for('home'))
    print(url_for('about'))
    
if __name__ ==
